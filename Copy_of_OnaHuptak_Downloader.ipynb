# %% [markdown]
# <a href="https://colab.research.google.com/github/vihanga24/Misaki-Md/blob/main/Copy_of_OnaHuptak_Downloader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><img src='https://drive.google.com/uc?export=view&id=1w4Wrp4RNpAYCElg773KPr87P0TR419cc' height="120" /> </center>
#
# # <center> **Indrajith's OnaHuptak Downloader**
#
# <center><b><h1>ඉන්ද්‍රජිත්ගේ ඕනහුප්ටක් ඩවුන්ලෝඩර් එක</b></h2></center>
# <center><h2>ඕනම Online වීඩියෝ එකක්, torrent එකක් හෝ කීපයක්,  direct link එකක් හෝ කීපයක්, TS හෝ m3u8 stream එකක්, mega.co.nz ලින්ක් එකක් තමන්ගේ Google drive එකට බා ගන්න මේකෙන් පුළුවන්.</h2></center>
# <justify><h8>මේකට උඹේ google drive එකට sign in වෙලා ඉන්න ඕන. උඹේ drive එකට <b>mount කරද්දී Google Drive එකට copy කරන්න අවසර ඉල්ලනවා. (warning : not authored by Google කියලා ආවොත් එතන run anyway කරහන්.)</b> ඒ ගැන බය වෙන්න එපා. කැමති අයට code එක බලන්න පුළුවන්. කිසිම privacy අවුලක් නෑ, උඹලා බාන දේවල් මටවත්, කාටවත් පේන්නේ නැහැ. පැය 12 කින් Disconnect වුණ ගමන් access අයින් වෙනවා. කැමති නම් කලින්ම runtime ගිහින් disconnect කරපන්. <b>Privacy අවුල්ම නම් මේකෙන් බාන්නම කියලා වෙනම google account එකක් හදා ගනින්. ඒකෙන් අමතර 15 GB කුත් හම්බෙනවානේ.</b></h8></justify></br>
# <justify><h8><br>දාන දේවල් දාලා <b>ඊතලෙන් පෙන්නලා තියෙන තැන තියෙන play වගේ button එක ඔබලා run කරාම හරි</b>. ඉවර වෙලා යටින් හරියක් වැටුණාම වැඩේ ඉවරයි. කැමති නම් ඉවර වෙනකල්ම බලාගෙන ඉන්නත් පුළුවන්, හැබැයි එහෙම ඕනෙම නෑ. <b>Run වෙන්න ගත්තාට පස්සේ මේකෙන් අයින් වුණත් download වෙලා උඹේ drive එකට ෆයිල් එක බෑවිලා තියෙයි.</b></h8></justify><br>
# <justify><h8><br>Any Video Downloader එකට සාමාන්‍යයෙන් වීඩියෝ play වෙන ඕනෑම site එකක් වැඩ. <B>YouTube (තනි වීඩියෝ සහ සම්පූර්ණ playlist), Facebook, Insta, Tiktok, Twitter, Snap, Linkedin, VK, Dailymotion</B> ඇතුළු social media සේරම, ප්‍රධාන <B>ජිල්😏 සහ Tube සයිට්</B> සේරම, Sports සහ News site, කොටින්ම සාමාන්‍යයෙන් <B>ප්‍රසිද්ධ ඕනෑම site එකක public play වෙන වීඩියෝ ඕන එකක්</B> මේකෙන් බාන්න පුළුවන්.<br>
# <justify><h8><br><B>ඊට පහළින් torrent download කරන්න, media නොවන ෆයිල් download කරන්න එහෙමත් cell තියෙනවා.</B> අවශ්‍ය විදිහට ඒවාත් පාවිච්චි කරන්න පුළුවන්.<br>
# <justify><h8><br>මොකක් හරි අපැහැදිලි තැනක් තිබුණොත් මම fb ඉන්නවා. මේක හදපු busyindrajith777@gmail.com මගේම email එක. 0777984078 මගේ WhatsApp නම්බර් එක. ඔය ඕන විදිහකින් මාව contact කරපන්.</b></h8></justify><br>
#
# <a href="https://www.facebook.com/indrajith.gamage">මගේ fb එක</a><br>
# <a href="https://wa.me/94777984078">මගේ WhatsApp එක</a>
#
# <center><h3>එහෙනම් මේක පාවිච්චි කරලා ඕන හුප්ටක් බා ගනින්. බුදු සරණයි!!

# %%
#@title ← දාන ටික දාලා මේක ඔබහන්. Any Video Downloader<center><br>  Public Video play වෙන ඕනම site එකක ලින්ක් එකක් දාලා, අවශ්‍ය options තෝරලා run කරපන්. නිකන්ම link එක දාලා run කරොත් default විදිහට බෑවෙයි.  </center><br> { display-mode: "form" }
import os
import shlex

Download_link = "" #@param {type:"string"}
#@markdown ######<center>තනි ලින්ක් එකක් නම් මෙතනට දාහන්. පහළින් තියෙන default options වෙනස් නොකර කෙළින්ම run කරත් වීඩියෝ එක බෑවෙයි.
Load_from_text = "No" #@param ["No", "Yes"]
#@markdown ######<center>කැමති නම් මේක Yes කරලා, text file එකකට අවශ්‍ය URL ටික දාලා (පේළියකට එක ගානේ enter ගහලා) Run කරාම එන upload option එකෙන් ඒ text file එක තෝරපන්. ඔක්කොම ටික එකපාර බෑවෙයි.
if Load_from_text == "Yes":
  # !find  *.txt -maxdepth 0 -type f -cmin -60 -size -1000c -delete > /dev/null 2>&1
  from google.colab import files
  urls = files.upload()
  for names in urls.keys():
    lists = '-a "' + names + '"'
File_name = "[Original]" #@param {type:"string"}
#@markdown ######<center>අවශ්‍ය නම් නමක් දාහන්. (extension එක ඉබේ වැටෙයි) තියෙන විදිහට තිබුණොත් වීඩියෝ එකේ තියෙන නම වැටෙයි. Text එකකින් කීපයක් load කරනවා නම් නම [original] ම තියපන්.
flname = shlex.quote(str(File_name+'.%(ext)s'))
Location = "drive/My Drive/OnaHuptak/" #@param {type:"string"}
#@markdown ######<center>කැමති නම් folder එකේ නම/path වෙනස් කරන්න පුළුවන්. තියෙන විදිහට තිබුණොත් <B> OnaHuptak </B> කියලා folder එකක් හැදිලා ඒකට බෑවෙයි.
Accelerator = "Off" #@param ["Off", "On"]
#@markdown ######<center>Download speed එක අඩු නම් මේක on කරලා multi thread accelerate කරන්න පුළුවන්. Progress එක තත්පර 5 න් 5 ට පෙන්නයි.
Trim = "No" #@param ["No", "00:00:00-00:00:00"] {allow-input: true}
trimmer = ""
if Trim != "No" and "00:00:00-00:00:00":
  trimmer = str("--download-sections *"+Trim)
#@markdown ######<center>කොටසක් බාන්න ඕන නම් පටන් ගන්න වෙලාවයි, අවසාන වෙලාවයි වෙනස් කරහන්. Drop down එකෙන් 00:00:00-00:00:00 අරන් පැය, විනාඩි, තත්පර ගණන් වෙනස් කරහන්.
Type = "MP4" #@param ["MP4", "MKV", "WEBM", "MP3"]
#@markdown ######<center>බෑවෙන වීඩියෝ එකේ වර්ගය මේකෙන් (mkv, mp4, webm) තෝරහන්. MP3 දැම්මාම audio කොටස විතරක් extract වෙලා save වෙයි.
Subtitles = "Off" #@param ["Off", "Embedded", "Autosub"]
#@markdown ######<center>Subtitle අරගෙන embed කරන්න ඕන නම් මේකෙන් embedded තෝරහන්. Autosub වලින් voice recognition එකෙන් ගන්න subtitles embed වෙනවා.

Resolution = "*Best available*" #@param ["*Best available*", "360p", "480p", "720p", "1080p", "144p", "240p", "1440p", "2160p", "Audio Only", "*Find available*"]
#@markdown ######<center>මෙතනින් resolution එක තෝරපන්. සමහර සයිට්/වීඩියෝවලට selection එක හරි නොයන්න පුළුවන්. එහෙම වුණොත් find available තෝරලා run කරලා, එන ලිස්ට් එකෙන් කැමති resolution එකේ ID එක යටින් තියෙන Res_ID එකේ ටයිප් කරලා ආයේ run කරහන්. (audio/video දෙකක් නම් VidID+AudID වගේ + ලකුණ එක්ක දෙකම) Best available තිබ්බාම හොඳම quality එක තෝරලා බෑවෙනවා.
Res_ID = ""#@param {type:"string"}
extt = ""
if Accelerator == "On":
  # !sudo apt-get install aria2 > /dev/null 2>&1
  extt = "--downloader aria2c --downloader-args '-j16 -x16 -s16 --summary-interval=5'"
MaxSize_MB = "15000" #@param {type:"string"}
MaxSize_MB = str(int(MaxSize_MB)*1048*1048)
#@markdown ######<center>උපරිම file size එකක් කැමති නම් මෙගාබයිට්වලින් දාහන්. Drive එකේ ඉඩ සීමිතයි නම් මේක වටිනවා. 15000MB කියන්නේ free google drive එකේ හම්බෙන උපරිම ඉඩ.

Make_Archive = "No" #@param ["No", "Zip_only", "Zip_and_Delete_files", "Rar_only", "Rar_and_Delete_files"]
#@markdown ######<center>මේක තියෙන්නේ බාන ෆයිල් සේරම ටික එකපාර PC එකට වගේ බාන්න පහසු වෙන්න Archive එකක් හදා ගන්නයි.
#@markdown ######<center>Zip only, Rar only තේරුවොත් තියෙන ෆයිල් ටික compress වෙලා zip හෝ rar එකකුත් හැදෙනවා. ෆයිල් ටිකත් ඉතිරි වෙනවා
#@markdown ######<center>Zip / Rar and delete files තේරුවොත් ෆයිල් සේරම compress වුණු zip හෝ rar එක විතරක් හැදෙනවා. මේ ක්‍රමයට කරාම drive එකේ ඉඩ වැය වෙන්නේ ඉතිරි වෙන zip හෝ rar ෆයිල් එකට විතරයි.
ag = "" #@param {type:"string"}
modifiers = "Autosub"
types = ""
subt = ""
if Subtitles == "Embedded":
  subt = "--embed-subs"
if Subtitles == "Autosub":
  subt = '--write-auto-subs --embed-subs --sub-langs "en.*,si.*"'

modifiers = ""
types = ""

# !sudo wget https://github.com/yt-dlp/yt-dlp-nightly-builds/releases/latest/download/yt-dlp -O /usr/local/bin/yt-dlp > /dev/null 2>&1
# !sudo chmod a+rx /usr/local/bin/yt-dlp > /dev/null 2>&1

if Resolution == "*Best available*":
  modifiers = '-f "bv+ba/b"'
elif Resolution == "360p":
  modifiers = '-f "bv*[height<=360]+ba/b"'
elif Resolution == "480p":
  modifiers = '-f "bv*[height<=480]+ba/b"'
elif Resolution == "720p":
  modifiers = '-f "bv*[height<=720]+ba/b"'
elif Resolution == "1080p":
  modifiers = '-f "bv*[height<=1080]+ba/b"'
elif Resolution == "144p":
  modifiers = '-f "bv*[height<=144]+wa/w"'
elif Resolution == "240p":
  modifiers = '-f "bv*[height<=240]+wa/w"'
elif Resolution == "1440p":
  modifiers = '-f "bv*[height<=1440]+ba/b"'
elif Resolution == "2160p":
  modifiers = '-f "bv*[height<=2160]+ba/b"'
elif Resolution == "Audio Only":
  modifiers = '-f "ba"'
elif Resolution == "*Find available*":
  modifiers = '--list-formats'
  if Res_ID != "":
    modifiers = '-f'+str(Res_ID)

if Type == "MP4":
  types = '-S ext:mp4:m4a'
if Type == "MKV":
  types = '--merge-output-format mkv'
if Type == "WEBM":
  types = '--merge-output-format webm'
if Type == "MP3":
  types = '-x --audio-format mp3'

from google.colab import drive
drive.mount("/content/drive/")

if File_name == "[Original]":
  if Load_from_text == "Yes":
    # !yt-dlp $ag $lists --no-warnings -P "$Location" $trimmer $modifiers $types --max-filesize $MaxSize_MB -o "%(height)sp_%(title)s.%(ext)s" $subt --trim-filenames 80 --windows-filenames $extt
    # !find  *.txt -maxdepth 0 -type f -cmin -60 -size -1000c -delete > /dev/null 2>&1
  else:
    # !yt-dlp $ag --no-warnings -P "$Location" "$Download_link" $trimmer $modifiers $types --max-filesize $MaxSize_MB -o "%(height)sp_%(title)s.%(ext)s" $subt --trim-filenames 80 --windows-filenames $extt
else:
  # !yt-dlp $ag --no-warnings -P "$Location" "$Download_link" $trimmer $modifiers $types --max-filesize $MaxSize_MB -o "$flname" --windows-filenames $subt $extt

if Make_Archive == "Zip_only":
  temp = Location.split("/")
  temp1 = temp[-2]
  temp2 = str(temp1+'.zip')
  # !zip "$Location$temp2" -r "$Location"
  print("කියපු විදිහට zip archive එකයි, බාපු ෆයිල් ටිකයි ඔක්කොම drive එකේ ඇති")

if Make_Archive == "Rar_only":
  # !apt-get install rar > /dev/null 2>&1
  temp = Location.split("/")
  temp1 = temp[-2]
  temp2 = str(temp1)
  # !rar a -m5 -ep "$Location$temp1" "$Location"
  print("කියපු විදිහට rar archive එකයි, බාපු ෆයිල් ටිකයි ඔක්කොම drive එකේ ඇති")

if Make_Archive == "Zip_and_Delete_files":
  temp = Location.split("/")
  temp1 = temp[-2]
  temp2 = str(temp1+'.zip')
  # !zip "$temp2" -r "$Location"
  # !rm -r "$Location"/*.*
  # !mv "$temp2" "$Location"
  print("කියපු විදිහට බාපු ෆයිල් ටිකෙන් තනි zip ෆයිල් එකක් හැදුවා. ඒක විතරක් drive එකේ ඇති")

if Make_Archive == "Rar_and_Delete_files":
  # !apt-get install rar > /dev/null 2>&1
  temp = Location.split("/")
  temp1 = temp[-2]
  temp2 = str(temp1)
  temp3 = ".rar"
  # !rar a -m5 -ep "$temp2" "$Location"
  # !rm -r "$Location"/*.*
  # !mv "$temp2$temp3" "$Location"
  print("කියපු විදිහට බාපු ෆයිල් ටිකෙන් තනි rar ෆයිල් එකක් හැදුවා. ඒක විතරක් drive එකේ ඇති")

print("දැන් හරි. උඩින් errors මොනවත් ඇවිත් නැත්නම් google drive එකේ ගිහින් බලහන්, ෆයිල් එක/ටික ඇති.")

# %%
#@title ← Run Torrent Downloader<center>  Magnet ලින්ක් එක (අවශ්‍ය නම් location) දාලා run කරපන් </center> { display-mode: "form" }
import os

# !pip install libtorrent > /dev/null 2>&1

import libtorrent as lt
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

ses = lt.session()
ses.listen_on(6881, 6891)
downloads = []

from google.colab import drive
drive.mount("/content/drive")

Magnet_link = "" #@param {type:"string"}
Location = "/content/drive/My Drive/" #@param {type:"string"}
#@markdown Magnet link දාලා තනි ටොරන්ට් එකක් බාන්න හොඳම ක්‍රමය මේක. බාගෙට නැවතුණත් resume වෙනවා.
# !mkdir -p "$Location"
params = {"save_path": Location}

magnet_link = Magnet_link
print("Downloading to ", Location)
downloads.append(
        lt.add_magnet_uri(ses, magnet_link, params)
)

import time

from IPython.display import display
import ipywidgets as widgets

state_str = [
    "queued",
    "checking",
    "downloading metadata",
    "downloading",
    "finished",
    "seeding",
    "allocating",
    "checking fastresume",
]

layout = widgets.Layout(width="auto")
style = {"description_width": "initial"}
download_bars = [
    widgets.FloatSlider(
        step=0.01, disabled=True, layout=layout, style=style
    )
    for _ in downloads
]
display(*download_bars)

while downloads:
    next_shift = 0
    for index, download in enumerate(downloads[:]):
        bar = download_bars[index + next_shift]
        if not download.is_seed():
            s = download.status()

            bar.description = " ".join(
                [
                    download.name(),
                    str(s.download_rate / 1000),
                    "kB/s",
                    state_str[s.state],
                ]
            )
            bar.value = s.progress * 100
        else:
            next_shift -= 1
            ses.remove_torrent(download)
            downloads.remove(download)
            bar.close()
            download_bars.remove(bar)
            print("Downloading වෙලා ඉවරයි. විනාඩි දෙකකින් විතර Google Drive එක බලපන්")
    time.sleep(1)
magnet_link = ""

# %%
#@title ← Run Torrent File Downloader<center> අවශ්‍ය නම් Location දාලා මේක run කරලා, prompt එක ආවාම browse/choose files ඔබලා, torrent file එක තෝරපන් </center> { display-mode: "form" }
import os

# !pip install libtorrent > /dev/null 2>&1

import libtorrent as lt
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

ses = lt.session()
ses.listen_on(6881, 6891)
downloads = []

from google.colab import drive
drive.mount("/content/drive")

Location = "/content/drive/My Drive/" #@param {type:"string"}
#@markdown Magnet link වෙනුවට torrent file එකක් upload කරලා බානවා නම් මේක පාවිච්චි කරන්න පුළුවන්. Resume සහිතයි.
# !mkdir -p "$Location"

from google.colab import files

source = files.upload()
params = {
    "save_path": "/content/drive/My Drive/Torrent",
    "ti": lt.torrent_info(list(source.keys())[0]),
}
downloads.append(ses.add_torrent(params))

import time

from IPython.display import display
import ipywidgets as widgets

state_str = [
    "queued",
    "checking",
    "downloading metadata",
    "downloading",
    "finished",
    "seeding",
    "allocating",
    "checking fastresume",
]

layout = widgets.Layout(width="auto")
style = {"description_width": "initial"}
download_bars = [
    widgets.FloatSlider(
        step=0.01, disabled=True, layout=layout, style=style
    )
    for _ in downloads
]
display(*download_bars)

while downloads:
    next_shift = 0
    for index, download in enumerate(downloads[:]):
        bar = download_bars[index + next_shift]
        if not download.is_seed():
            s = download.status()

            bar.description = " ".join(
                [
                    download.name(),
                    str(s.download_rate / 1000),
                    "kB/s",
                    state_str[s.state],
                ]
            )
            bar.value = s.progress * 100
        else:
            next_shift -= 1
            ses.remove_torrent(download)
            downloads.remove(download)
            bar.close()
            download_bars.remove(bar)
            print("Downloading වෙලා ඉවරයි. විනාඩි දෙකකින් විතර Google Drive එක බලපන්")
    time.sleep(1)
magnet_link = ""

# %%
#@title ← Run Multy file Torrent index based Downloader <center>  Magnet ලින්ක් / torrent ෆයිල් එක (අවශ්‍ය නම් location) දාලා run කරලා, එන ලිස්ට් එකෙන් index තෝරලා දාලා ආයේ run කරපන් </center> { display-mode: "form" }

Magnet_link = "" #@param {type:"string"}
Torrent_upload = "No" #@param ["No", "Yes"]
#@markdown #####Magnet නම් link එක දාහන්. නැතිව Torrent එක upload කරන්න ඕන නම් මේක yes දාලා run කරලා prompt එකෙන් torrent file එක තෝරපන්.
Indexes = "" #@param {type:"string"}
#@markdown #####මුලින් run කරලා එන ලිස්ට් එකෙන් index එක අනුව අදාළ file 1,2,5,10 විදිහට comma දාලා හරි, 3-7 වගේ range හරි දියන්. Combine කරලා 1,4,10-20,33 වගෙත් පුළුවන්.
Location = "drive/MyDrive/OnaHuptak/" #@param {type:"string"}

# !sudo apt-get install aria2 > /dev/null 2>&1

if Indexes=="" and Torrent_upload == "No":
  # !aria2c --summary-interval=5 --bt-metadata-only=true --bt-save-metadata=true '{Magnet_link}'
  # !mv $(ls -t | head -1) my.torrent
  # !aria2c -S my.torrent

elif Indexes=="" and Torrent_upload == "Yes":
  from google.colab import files
  import os
  uploaded = files.upload()
  os.rename(list(uploaded.keys())[0], 'my.torrent')
  # !aria2c -S my.torrent

if Indexes!="":
  from google.colab import drive
  drive.mount("/content/drive/")
  # !mkdir -p "$Location"

  # !aria2c --select-file="$Indexes" my.torrent --summary-interval=5 --seed-time=0 -d "$Location"
  # !rm my.torrent

# %%
#@title ← Run Aria2c Downloader with Resume<center>  ලින්ක් එකකුයි, නමකුයි (අවශ්‍ය නම් location) දාලා, connection ගාණක් තෝරලා run කරපන්. </center> { display-mode: "form" }
import os
from google.colab.output import eval_js
eval_js('google.colab.output.setIframeHeight("250")')

Download_link = "" #@param {type:"string"}
File_name = "[Original]" #@param {type:"string"}
Load_from_text = "No" #@param ["No", "Yes"]
if Load_from_text == "Yes":
  # !find  *.txt -maxdepth 0 -type f -cmin -60 -size -1000c -delete > /dev/null 2>&1
  from google.colab import files
  urls = files.upload()
  for names in urls.keys():
    lists = '-i '+names
Location = "drive/MyDrive/OnaHuptak/" #@param {type:"string"}
Connections = "16" #@param [1, 2, 4, 8, 12, 16] {allow-input: false}
#@markdown Aria2c එක ලොකු ෆයිල්, නිතර link වෙනස් වෙන file එහෙම බාන්න වඩාත් හොඳයි. කැමති නම් load from text වලට Yes තෝරලා text file එකකට දාපු ලින්ක් list එකක්ම එක සැරේ වුණත් බා ගන්න පුළුවන්. Text file එකකින් බානවා නම් File name එක [Original] තියෙන්න ඕන.
Connections = int(Connections)

from google.colab import drive
drive.mount("/content/drive/")

# !sudo apt-get install aria2 > /dev/null 2>&1
if File_name != "[Original]":
  # !aria2c -x$Connections -s$Connections -j$Connections "$Download_link" -d "$Location" -o "$File_name" --summary-interval=5 --seed-time=0
else:
  if Load_from_text == "Yes":
    # !aria2c -x$Connections -s$Connections -j$Connections "$lists" -d "$Location" --summary-interval=5 --seed-time=0
    # !find  *.txt -maxdepth 0 -type f -cmin -60 -size -1000c -delete > /dev/null 2>&1
  else:
    # !aria2c -x$Connections -s$Connections -j$Connections "$Download_link" -d "$Location" --summary-interval=5 --seed-time=0
print("දැන් හරි. Drive එකේ බලපන්.")

# %%
#@title ← Run Accelerated Downloader with Resume<center>  ලින්ක් එකකුයි, නමකුයි (අවශ්‍ය නම් location) දාලා, connection ගාණක් තෝරලා run කරපන් </center> { display-mode: "form" }
import os

Download_link = "" #@param {type:"string"}
File_name = "[Original]" #@param {type:"string"}
Location = "drive/MyDrive/OnaHuptak/" #@param {type:"string"}
Connections = "32" #@param [1, 2, 4, 8, 16, 32, 64] {allow-input: true}
Connections = int(Connections)
#@markdown Connections ගොඩක් තියා ගන්න දෙන file වලට මේක හොඳයි. මේ downloader එක fail වෙනවා නම් connections ගාණ අඩු කරලා ට්‍රයි කරහන්.

from google.colab import drive
drive.mount("/content/drive/")
# !mkdir -p "$Location"

# !sudo apt update --assume-yes axel > /dev/null 2>&1
# !sudo apt install --assume-yes axel > /dev/null 2>&1
print("Downloading...")
if File_name == "[Original]":
  # !axel -n $Connections -o "$Location" "$Download_link" | tr '\n' '\r'
else:
  # !axel -n $Connections -o "$Location$File_name" "$Download_link" | tr '\n' '\r'
print("\n")
print("දැන් හරි. Drive එකේ බලපන්.")

# %%
#@title ← Run Multy Torrent Downloader <center> </font>  මේකෙන් කැමති Torrent ගාණක් එකපාර බාපන් </center> { display-mode: "form" }
#@markdown #####කැමති location එකක් දාලා Run කරාම අහන ප්‍රශ්නවලට අනුව Torrent ගාණ දාලා enter කරපන්..
#@markdown #####ඊට පස්සේ එකෙන් එකට Magnet ලින්ක් ටික දාගෙන යන්න තියෙන්නෙ.
#@markdown #####දාලා ඉවර වුණාම එක දිගට සේරම බෑවෙනවා. තත්පර දහයෙන් දහයට torrent එකේ status update එයි.
import os

from google.colab import drive
drive.mount("/content/drive/")
Location = "drive/MyDrive/OnaHuptak/" #@param {type:"string"}
# !mkdir -p "$Location"

total = input("Torrent කීයක්ද මචන්? (ඉලක්කමක් දාලා enter කරපන්) : ")
total = int(total)
link = [""]*total
Templink = ""
for i in range (total):
  print ("Torrent අංක", i+1)
  link[i] = input("Magnet link එක දාලා enter ගහපන් : ")
  print ("හරි, දැන් ඊළඟ එක..")

# !sudo apt-get install aria2 > /dev/null 2>&1

for j in range (total):
  Templink = link[j]
  print("දැන් බාන්නෙ :", j+1, "වන Torrent එක")
  print(Templink)
  # !aria2c -x16 "$Templink" -d "$Location" --summary-interval=10 --seed-time=0
  print("මේක බාලා ඉවරයි. Drive එකේ බලපන්.")

print("වැඩේ හරි, උඹ දාපු Torrent ", total, "ම බාලා ඉවරයි.")

# %%
from google.colab import drive
drive.mount("/content/drive/")

import os
# !apt-get --purge remove install megatools -y > /dev/null 2>&1
# !apt-get install megatools -y

#@title  ← Run Mega Downloader<center>  MEGA ලින්ක් එකක් (අවශ්‍ය නම් location) දාලා run කරපන් </center> { display-mode: "form" }

MEGA_URL = "" #@param {type:"string"}
LOCATION = "/content/drive/MyDrive/OnaHuptak/" #@param {type:"string"}
#@markdown #####_*සමහර වෙලාවට මේක ඉබේ නතර වෙන්නේ නැහැ. එහෙම වුණොත් stop කරපන්_

os.makedirs(LOCATION, exist_ok=True)

# !megadl "{MEGA_URL}" --path "{LOCATION}"

# %%
#@title ← Run Compress <center>  Compress කරන Archive එකේ වර්ගය, Folder/file එක තියෙන තැන, archive එක හැදෙන්න ඕන තැන දාලා run කරපන් </center> { display-mode: "form" }
import os
Archive_type = ".rar" #@param [".zip", ".rar", ".7z", ".tar", ".tar.gz"]
#@markdown <center>මෙතනින් හදන්න අවශ්‍ය archive එකේ වර්ගය තෝරපන්.
File_location = "/content/drive/My Drive/OnaHuptak/" #@param {type:"string"}
#@markdown <center>මෙතනට archive එක හදන්න අවශ්‍ය file එක හෝ folder එක තියෙන දාපන්. File නම් extension එක්ක, folder නම් / එකකින් අවසන් වෙන්න ඕන.
Archive_location = "/content/drive/My Drive/example" #@param {type:"string"}
#@markdown <center>මෙතනට archive එක හදන්න අවශ්‍ය තැනයි, නමයි දාපන්. තියෙන විදිහට තිබ්බොත් root එකේ example.xxx කියලා හැදෙයි

from google.colab import drive
drive.mount("/content/drive/")

if Archive_type == ".zip":
  # !zip "$Archive_location$Archive_type" -r -j "$File_location"

if Archive_type == ".rar":
  # !apt-get install rar > /dev/null 2>&1
  temp = File_location[:-1]
  # !rar a -m5 -ep "$Archive_location" "$temp"

if Archive_type == ".7z":
  # !apt-get install p7zip-full > /dev/null 2>&1
  !7z a "$Archive_location$Archive_type" .\"$File_location"

if Archive_type == ".tar":
  # !apt-get install p7zip-full > /dev/null 2>&1
  # !tar -cvf "$Archive_location$Archive_type" -C "$File_location" .

if Archive_type == ".tar.gz":
  # !apt-get install p7zip-full > /dev/null 2>&1
  # !tar -czvf -m5 "$Archive_location$Archive_type" "$File_location"

# %%
#@title ← Run Extractor (Extract කරන්න මේ cell එක)<center>  Archive එකේ වර්ගය, තියෙන තැන, extract කරන folder එක දාලා run කරපන් </center> { display-mode: "form" }
import os
Archive_type = ".zip" #@param [".zip", ".rar", ".7z", ".tar", ".tar.gz"]
#@markdown <center>මේකෙන් archive එකේ වර්ගය මොකක්ද කියලා තෝරපන්
Archive_location = "/content/drive/My Drive/example" #@param {type:"string"}
#@markdown <center>මෙතනට <b>*extension නැතිව</b> archive එකේ නම සහ location එක දාපන්. content/drive/My Drive/example කියන්නේ root එකේ තියෙන example.xxx කියලා archive එකක්.
Extract_location = "/content/drive/My Drive/Extract/" #@param {type:"string"}
#@markdown <center>මෙතනට extract වෙන්න අවශ්‍ය තැන දාපන්. තියෙන විදිහටම තිබ්බොත් root එකේ Extract කියලා folder එකකට (එහෙම එකක් නැත්නම් folder එක හැදිලා) extract වෙයි.


from google.colab import drive
drive.mount("/content/drive/")

if Archive_type == ".zip":
  # !unzip "$Archive_location$Archive_type" -d "$Extract_location"

if Archive_type == ".rar":
  # !unrar x -Y "$Archive_location$Archive_type" "$Extract_location"

if Archive_type == ".7z":
  !7z x "$Archive_location$Archive_type" -o"$Extract_location"

if Archive_type == ".tar":
  # !mkdir "$Extract_location"
  # !tar -xvf "$Archive_location$Archive_type" -C "$Extract_location"

if Archive_type == ".tar.gz":
  # !mkdir "$Extract_location"
  # !tar -xzvf "$Archive_location$Archive_type" -C "$Extract_location"

# %%
#@title ← RUN 7z Password Extract <center>  7zip path එකයි, Extract location එකයි, password එකයි දාලා run කරපන් </center> { display-mode: "form" }

import os
import subprocess
from google.colab import drive

# Define locations and password (can be input through the form interface)
Archive_location = "/content/drive/MyDrive/OnaHuptak/.7z" #@param {type:"string"}
Extract_location = "/content/drive/MyDrive/OnaHuptak/" #@param {type:"string"}
Password = "" #@param {type:"string"}

# Create extraction directory if it doesn't exist
os.makedirs(Extract_location, exist_ok=True)

# Install 7zip if not already installed
# !apt-get install -y p7zip-full

# Command to extract the .7z archive with the provided password
extract_command = f'7z x -p"{Password}" "{Archive_location}" -o"{Extract_location}"'

try:
    # Run the extraction command
    result = subprocess.run(extract_command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Check if password was wrong by inspecting the output
    if "Wrong password" in result.stdout or "Wrong password" in result.stderr:
        print("Extraction failed: Wrong password.")
    elif result.returncode == 0:
        print("Extraction successful.")
    else:
        print(f"Extraction failed with error: {result.stderr}")
except Exception as e:
    print(f"Error occurred: {e}")

# %%
#@title Proxy
#@markdown Proxy එකකින් බාන්න ඕන නම් Proxy:Port මෙතනට දාලා run කරහන්. තියෙන්නෙ හොඳ fast, default තුනක්. 85 එක Russian, 20 එක USA, 190 එක Venezuela.
Proxy_port = "85.172.15.98:80" #@param ["20.99.187.69:8443", "190.6.23.218:999", "85.172.15.98:80"] {allow-input: true}
# %env https_proxy=$Proxy_port
print("දැන් හරි, close කරනකල් දාපු proxy ය වැඩ")
